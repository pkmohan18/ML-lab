# %%
class Graph:
    def __init__(self,graph,hlist,startNode):
        self.graph=graph
        self.H=hlist
        self.start=startNode
        self.parent={}
        self.status={}
        self.solutionGraph={}
        
    def applyAOStar(self):
        self.aoStar(self.start,False)
        
    def getNeighbors(self,v):
        return self.graph.get(v,'')
    
    def getStatus(self,v):
        return self.status.get(v,0)
        
    def setStatus(self,v,val):
        self.status[v]=val
    
    def gethvalue(self,n):
        return self.H.get(n,0)
    
    def sethvalue(self,n,value):
        self.H[n]=value
        
    def printSolution(self):
        print("FOR GRAPH SOLUTION, TRAVERSE THE GRAPH FROM THE START NODE:",self.start)
        print("---------------------------------------")
        print(self.solutionGraph)
        print("---------------------------------------")
        
    def computemincost(self,v):
        minimumCost=0
        costtochild={}
        costtochild[minimumCost]=[]
        flag=True
        for nodeInfoTupleList in self.getNeighbors(v):
            cost=0
            nodeList=[]
            for c,weight in nodeInfoTupleList:
                cost=cost+self.gethvalue(c)+weight
                nodeList.append(c)
            if flag==True:
                minimumCost=cost
                costtochild[minimumCost]=nodeList
                flag=False
            else:
                if minimumCost>cost:
                    minimumCost=cost
                    costtochild[minimumCost]=nodeList
                    
        return minimumCost,costtochild[minimumCost]
    
    def aoStar(self,v,btrack):
        print("HEURISTIC VALUES:",self.H)
        print("SOLUTION GRAPH:",self.solutioGraph)
        print("PROCESSING NODE:",v)
        print("-----------------------------------")
        
        if self.getStatus(v)>=0:
            minimumCost,childNodeListt=self.computemincost(v)
            self.sethvalue(v,minimumCost)
            self.setStatus(v,len(childNodeList))
            
            solved=True
            for childNode in childNodeList:
                self.parent[childNode]=v
                if self.getStatus(childNode)!=-1:
                    solved=solved & False
                    
        if solved==True:
            self.setStatus(v,-1)
            self.solutionGraph[v]=childNodeList
            
        if v!=self.start:
            self.aoStar(self.parent[v],True)
            
        if btrack==False:
            for childNode in childNodeList:
                self.setStatus(childNode,0)
                self.aoStar(childNode,False)
                
h1={'A':1,'B':6,'C':2,'D':12,'E':2,'F':1,'G':5,'H':7,'I':7,'J':1}
graph1={
    'A':[[('B',1),('C',1)],[('D',1)]],
    'B':[[('G',1)],[('H',1)]],
    'C':[[('J',1)]],
    'D':[[('E',1),('F',1)]],
    'G':[[('I',1)]]
}
G1=Graph(graph1,h1,'A')
G1.applyAOStar()
G1.printSolution()

print("HEURISTIC VALUES:",G1.H)
print("SOLUTION GRAPH:",G1.solutionGraph)
# Out:
# HEURISTIC VALUES: {'A': 1, 'B': 6, 'C': 2, 'D': 12, 'E': 2, 'F': 1, 'G': 5, 'H': 7, 'I': 7, 'J': 1}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1616/3936528924.py in <module>
#      92 }
#      93 G1=Graph(graph1,h1,'A')
# ---> 94 G1.applyAOStar()
#      95 G1.printSolution()
#      96
#
# ~\AppData\Local\Temp/ipykernel_1616/3936528924.py in applyAOStar(self)
#       9
#      10     def applyAOStar(self):
# ---> 11         self.aoStar(self.start,False)
#      12
#      13     def getNeighbors(self,v):
#
# ~\AppData\Local\Temp/ipykernel_1616/3936528924.py in aoStar(self, v, btrack)
#      56     def aoStar(self,v,btrack):
#      57         print("HEURISTIC VALUES:",self.H)
# ---> 58         print("SOLUTION GRAPH:",self.solutioGraph)
#      59         print("PROCESSING NODE:",v)
#      60         print("-----------------------------------")
#
# ...
